# %% [markdown]
# # Data Analysis of the ticker's data to predict the stock price in the future

# %%
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Get data from json

# %%
with open("./temp/history_of_stock.json") as f:
    data = json.load(f)['results']

# %%
df = pd.DataFrame(data)
df = df.rename(columns={'v': 'volume', 'vw' : 'volume weighted', 'o': 'open', 'c': 'close', 'h': 'high', 'l': 'low', 't': 'time', 'n': 'transaction'}).set_index('time')

df
# Out:
#                   volume  volume weighted     open   close      high     low  \
# time
# 1643864400000   89418074         174.3835  174.480  172.90  176.2399  172.12
# 1643950800000   82446700         172.3165  171.680  172.39  174.1000  170.68
# 1644210000000   77251204         172.4426  172.860  171.66  173.9458  170.95
# 1644296400000   74829217         173.8127  171.730  174.83  175.3500  171.43
# 1644382800000   71204538         175.8287  176.050  176.28  176.6500  174.90
# ...                  ...              ...      ...     ...       ...     ...
# 1706504400000   47145622         191.2954  192.010  191.73  192.2000  189.58
# 1706590800000   55836970         188.7927  190.940  188.04  191.8000  187.47
# 1706677200000   55467803         185.3525  187.040  184.40  187.0950  184.35
# 1706763600000   64885408         185.5688  183.985  186.86  186.9500  183.82
# 1706850000000  102527680         184.7440  179.860  185.85  187.3300  179.25
#
#                transaction
# time
# ...

# %% [markdown]
# # Starting Analysis
